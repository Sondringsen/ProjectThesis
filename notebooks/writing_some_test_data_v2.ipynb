# %%
import pandas as pd
import numpy as np
import pickle

# %%
def process_data(ticker, path_to_data, sequence_length, num_sequences, num_eval_points, no_eval_fraction, output_path):
    # Read the CSV data
    print("Reading CSV data...")
    df = pd.read_csv(path_to_data)

    # Filter by ticker and discard the ticker column
    df = df[df['ticker'] == ticker].copy()
    df.drop(columns=['ticker'], inplace=True)
    df.reset_index(drop=True, inplace=True)

    # Ensure the DataFrame is sorted by sip_timestamp
    df.sort_values(by='sip_timestamp', inplace=True)
    df.reset_index(drop=True, inplace=True)

    N = len(df)
    if N < sequence_length:
        raise ValueError("Not enough data to create sequences of the given length.")

    # Generate random starting indices for sequences
    max_start_index = N - sequence_length
    start_indices = np.random.randint(0, max_start_index + 1, size=num_sequences * 2)  # Generate extra indices

    sequences = []
    for i, idx in enumerate(start_indices):
        if len(sequences) >= num_sequences:
            break  # We have enough sequences

        print(f"Processing sequence {len(sequences)+1}/{num_sequences}")
        # Extract the sequence of data
        seq_df = df.iloc[idx:idx + sequence_length].copy()
        ts = seq_df['sip_timestamp'].values
        xs = seq_df.drop(columns=['sip_timestamp']).values

        # Verify the sequence length
        if len(ts) != sequence_length or len(xs) != sequence_length:
            print(f"Warning: Sequence at index {idx} has incorrect length {len(ts)}. Skipping this sequence.")
            continue  # Skip this sequence

        # Generate ts_eval
        min_ts_seq = ts.min()
        max_ts_seq = ts.max()
        min_ts_eval = min_ts_seq + no_eval_fraction * (max_ts_seq - min_ts_seq)

        ts_set = set(ts)
        ts_eval = []
        attempts = 0
        max_attempts = num_eval_points * 10  # To prevent infinite loop
        while len(ts_eval) < num_eval_points and attempts < max_attempts:
            t_candidate = np.random.uniform(min_ts_eval, max_ts_seq)
            if t_candidate not in ts_set and t_candidate not in ts_eval:
                ts_eval.append(t_candidate)
            attempts += 1

        if len(ts_eval) < num_eval_points:
            print(f"Warning: Could not generate enough evaluation timestamps for sequence at index {idx}. Skipping this sequence.")
            continue  # Skip this sequence

        ts_eval.sort()
        ts_eval = np.array(ts_eval)

        # Compute ys_eval
        ys_eval = []
        for t in ts_eval:
            y = find_y_value(df, t)
            ys_eval.append(y)
        ys_eval = np.array(ys_eval)

        # Verify that ys_eval has the correct length and contains valid values
        if len(ys_eval) != num_eval_points or np.isnan(ys_eval).any():
            print(f"Warning: ys_eval for sequence at index {idx} has incorrect length or contains NaN values. Skipping this sequence.")
            continue  # Skip this sequence

        # Append the sequence
        sequences.append((ts, xs, ts_eval, ys_eval))

    # Check if we have enough sequences
    if len(sequences) < num_sequences:
        print(f"Warning: Only {len(sequences)} sequences were generated out of requested {num_sequences}.")

    # Save the sequences to a file
    with open(output_path, 'wb') as f:
        pickle.dump(sequences, f)
    print(f"Saved {len(sequences)} sequences to {output_path}")

def find_y_value(df, t):
    df_after_t = df[df['sip_timestamp'] > t]
    if df_after_t.empty:
        # Return the last known last_trade_price
        return df['last_trade_price'].iloc[-1]
    else:
        idx = df_after_t.index[0]
        last_trade_price_i = df.at[idx, 'last_trade_price']
        last_trade_price_prev = df.at[idx - 1, 'last_trade_price'] if idx > 0 else last_trade_price_i

        if last_trade_price_i != last_trade_price_prev:
            return last_trade_price_i
        else:
            # Compare other columns except 'last_trade_size'
            row_i_except_size = df.loc[idx].drop(labels='last_trade_size')
            row_prev_except_size = df.loc[idx - 1].drop(labels='last_trade_size') if idx > 0 else row_i_except_size

            if row_i_except_size.equals(row_prev_except_size):
                return last_trade_price_i
            else:
                # If no change is found, return the last known last_trade_price
                return df['last_trade_price'].iloc[-1]

# %%
process_data(
    ticker='V',
    path_to_data='../data/processed/2024-09-06.csv',
    sequence_length=24,
    num_sequences=1024,
    num_eval_points=8,
    no_eval_fraction=0.2,
    output_path='../data/processed/Visa_2024-09-06.pkl'
)
# Out:
# Reading CSV data...
# Processing sequence 1/1024
# Processing sequence 2/1024
# Processing sequence 3/1024
# Processing sequence 4/1024
# Processing sequence 5/1024
# Processing sequence 6/1024
# Processing sequence 7/1024
# Processing sequence 8/1024
# Processing sequence 9/1024
# Processing sequence 10/1024
# Processing sequence 11/1024
# Processing sequence 12/1024
# Processing sequence 13/1024
# Processing sequence 14/1024
# Processing sequence 15/1024
# Processing sequence 16/1024
# Processing sequence 17/1024
# Processing sequence 18/1024
# Processing sequence 19/1024
# Processing sequence 20/1024
# Processing sequence 21/1024
# Processing sequence 22/1024
# Processing sequence 23/1024
# Processing sequence 24/1024
# Processing sequence 25/1024
# Processing sequence 26/1024
# Processing sequence 27/1024
# Processing sequence 28/1024
# Processing sequence 29/1024
# Processing sequence 30/1024
# Processing sequence 31/1024
# Processing sequence 32/1024
# Processing sequence 33/1024
# Processing sequence 34/1024
# Processing sequence 35/1024
# Processing sequence 36/1024
# Processing sequence 37/1024
# Processing sequence 38/1024
# Processing sequence 39/1024
# Processing sequence 40/1024
# Processing sequence 41/1024
# Processing sequence 42/1024
# Processing sequence 43/1024
# Processing sequence 44/1024
# Processing sequence 45/1024
# Processing sequence 46/1024
# Processing sequence 47/1024
# Processing sequence 48/1024
# Processing sequence 49/1024
# Processing sequence 50/1024
# Processing sequence 51/1024
# Processing sequence 52/1024
# Processing sequence 53/1024
# Processing sequence 54/1024
# Processing sequence 55/1024
# Processing sequence 56/1024
# Processing sequence 57/1024
# Processing sequence 58/1024
# Processing sequence 59/1024
# Processing sequence 60/1024
# Processing sequence 61/1024
# Processing sequence 62/1024
# Processing sequence 63/1024
# Processing sequence 64/1024
# Processing sequence 65/1024
# Processing sequence 66/1024
# Processing sequence 67/1024
# Processing sequence 68/1024
# Processing sequence 69/1024
# Processing sequence 70/1024
# Processing sequence 71/1024
# Processing sequence 72/1024
# Processing sequence 73/1024
# Processing sequence 74/1024
# Processing sequence 75/1024
# Processing sequence 76/1024
# Processing sequence 77/1024
# Processing sequence 78/1024
# Processing sequence 79/1024
# Processing sequence 80/1024
# Processing sequence 81/1024
# Processing sequence 82/1024
# Processing sequence 83/1024
# Processing sequence 84/1024
# Processing sequence 85/1024
# Processing sequence 86/1024
# Processing sequence 87/1024
# Processing sequence 88/1024
# Processing sequence 89/1024
# Processing sequence 90/1024
# Processing sequence 91/1024
# Processing sequence 92/1024
# Processing sequence 93/1024
# Processing sequence 94/1024
# Processing sequence 95/1024
# Processing sequence 96/1024
# Processing sequence 97/1024
# Processing sequence 98/1024
# Processing sequence 99/1024
# Processing sequence 100/1024
# Processing sequence 101/1024
# Processing sequence 102/1024
# Processing sequence 103/1024
# Processing sequence 104/1024
# Processing sequence 105/1024
# Processing sequence 106/1024
# Processing sequence 107/1024
# Processing sequence 108/1024
# Processing sequence 109/1024
# Processing sequence 110/1024
# Processing sequence 111/1024
# Processing sequence 112/1024
# Processing sequence 113/1024
# Processing sequence 114/1024
# Processing sequence 115/1024
# Processing sequence 116/1024
# Processing sequence 117/1024
# Processing sequence 118/1024
# Processing sequence 119/1024
# Processing sequence 120/1024
# Processing sequence 121/1024
# Processing sequence 122/1024
# Processing sequence 123/1024
# Processing sequence 124/1024
# Processing sequence 125/1024
# Processing sequence 126/1024
# Processing sequence 127/1024
# Processing sequence 128/1024
# Processing sequence 129/1024
# Processing sequence 130/1024
# Processing sequence 131/1024
# Processing sequence 132/1024
# Processing sequence 133/1024
# Processing sequence 134/1024
# Processing sequence 135/1024
# Processing sequence 136/1024
# Processing sequence 137/1024
# Processing sequence 138/1024
# Processing sequence 139/1024
# Processing sequence 140/1024
# Processing sequence 141/1024
# Processing sequence 142/1024
# Processing sequence 143/1024
# Processing sequence 144/1024
# Processing sequence 145/1024
# Processing sequence 146/1024
# Processing sequence 147/1024
# Processing sequence 148/1024
# Processing sequence 149/1024
# Processing sequence 150/1024
# Processing sequence 151/1024
# Processing sequence 152/1024
# Processing sequence 153/1024
# Processing sequence 154/1024
# Processing sequence 155/1024
# Processing sequence 156/1024
# Processing sequence 157/1024
# Processing sequence 158/1024
# Processing sequence 159/1024
# Processing sequence 160/1024
# Processing sequence 161/1024
# Processing sequence 162/1024
# Processing sequence 163/1024
# Processing sequence 164/1024
# Processing sequence 165/1024
# Processing sequence 166/1024
# Processing sequence 167/1024
# Processing sequence 168/1024
# Processing sequence 169/1024
# Processing sequence 170/1024
# Processing sequence 171/1024
# Processing sequence 172/1024
# Processing sequence 173/1024
# Processing sequence 174/1024
# Processing sequence 175/1024
# Processing sequence 176/1024
# Processing sequence 177/1024
# Processing sequence 178/1024
# Processing sequence 179/1024
# Processing sequence 180/1024
# Processing sequence 181/1024
# Processing sequence 182/1024
# Processing sequence 183/1024
# Processing sequence 184/1024
# Processing sequence 185/1024
# Processing sequence 186/1024
# Processing sequence 187/1024
# Processing sequence 188/1024
# Processing sequence 189/1024
# Processing sequence 190/1024
# Processing sequence 191/1024
# Processing sequence 192/1024
# Processing sequence 193/1024
# Processing sequence 194/1024
# Processing sequence 195/1024
# Processing sequence 196/1024
# Processing sequence 197/1024
# Processing sequence 198/1024
# Processing sequence 199/1024
# Processing sequence 200/1024
# Processing sequence 201/1024
# Processing sequence 202/1024
# Processing sequence 203/1024
# Processing sequence 204/1024
# Processing sequence 205/1024
# Processing sequence 206/1024
# Processing sequence 207/1024
# Processing sequence 208/1024
# Processing sequence 209/1024
# Processing sequence 210/1024
# Processing sequence 211/1024
# Processing sequence 212/1024
# Processing sequence 213/1024
# Processing sequence 214/1024
# Processing sequence 215/1024
# Processing sequence 216/1024
# Processing sequence 217/1024
# Processing sequence 218/1024
# Processing sequence 219/1024
# Processing sequence 220/1024
# Processing sequence 221/1024
# Processing sequence 222/1024
# Processing sequence 223/1024
# Processing sequence 224/1024
# Processing sequence 225/1024
# Processing sequence 226/1024
# Processing sequence 227/1024
# Processing sequence 228/1024
# Processing sequence 229/1024
# Processing sequence 230/1024
# Processing sequence 231/1024
# Processing sequence 232/1024
# Processing sequence 233/1024
# Processing sequence 234/1024
# Processing sequence 235/1024
# Processing sequence 236/1024
# Processing sequence 237/1024
# Processing sequence 238/1024
# Processing sequence 239/1024
# Processing sequence 240/1024
# Processing sequence 241/1024
# Processing sequence 242/1024
# Processing sequence 243/1024
# Processing sequence 244/1024
# Processing sequence 245/1024
# Processing sequence 246/1024
# Processing sequence 247/1024
# Processing sequence 248/1024
# Processing sequence 249/1024
# Processing sequence 250/1024
# Processing sequence 251/1024
# Processing sequence 252/1024
# Processing sequence 253/1024
# Processing sequence 254/1024
# Processing sequence 255/1024
# Processing sequence 256/1024
# Processing sequence 257/1024
# Processing sequence 258/1024
# Processing sequence 259/1024
# Processing sequence 260/1024
# Processing sequence 261/1024
# Processing sequence 262/1024
# Processing sequence 263/1024
# Processing sequence 264/1024
# Processing sequence 265/1024
# Processing sequence 266/1024
# Processing sequence 267/1024
# Processing sequence 268/1024
# Processing sequence 269/1024
# Processing sequence 270/1024
# Processing sequence 271/1024
# Processing sequence 272/1024
# Processing sequence 273/1024
# Processing sequence 274/1024
# Processing sequence 275/1024
# Processing sequence 276/1024
# Processing sequence 277/1024
# Processing sequence 278/1024
# Processing sequence 279/1024
# Processing sequence 280/1024
# Processing sequence 281/1024
# Processing sequence 282/1024
# Processing sequence 283/1024
# Processing sequence 284/1024
# Processing sequence 285/1024
# Processing sequence 286/1024
# Processing sequence 287/1024
# Processing sequence 288/1024
# Processing sequence 289/1024
# Processing sequence 290/1024
# Processing sequence 291/1024
# Processing sequence 292/1024
# Processing sequence 293/1024
# Processing sequence 294/1024
# Processing sequence 295/1024
# Processing sequence 296/1024
# Processing sequence 297/1024
# Processing sequence 298/1024
# Processing sequence 299/1024
# Processing sequence 300/1024
# Processing sequence 301/1024
# Processing sequence 302/1024
# Processing sequence 303/1024
# Processing sequence 304/1024
# Processing sequence 305/1024
# Processing sequence 306/1024
# Processing sequence 307/1024
# Processing sequence 308/1024
# Processing sequence 309/1024
# Processing sequence 310/1024
# Processing sequence 311/1024
# Processing sequence 312/1024
# Processing sequence 313/1024
# Processing sequence 314/1024
# Processing sequence 315/1024
# Processing sequence 316/1024
# Processing sequence 317/1024
# Processing sequence 318/1024
# Processing sequence 319/1024
# Processing sequence 320/1024
# Processing sequence 321/1024
# Processing sequence 322/1024
# Processing sequence 323/1024
# Processing sequence 324/1024
# Processing sequence 325/1024
# Processing sequence 326/1024
# Processing sequence 327/1024
# Processing sequence 328/1024
# Processing sequence 329/1024
# Processing sequence 330/1024
# Processing sequence 331/1024
# Processing sequence 332/1024
# Processing sequence 333/1024
# Processing sequence 334/1024
# Processing sequence 335/1024
# Processing sequence 336/1024
# Processing sequence 337/1024
# Processing sequence 338/1024
# Processing sequence 339/1024
# Processing sequence 340/1024
# Processing sequence 341/1024
# Processing sequence 342/1024
# Processing sequence 343/1024
# Processing sequence 344/1024
# Processing sequence 345/1024
# Processing sequence 346/1024
# Processing sequence 347/1024
# Processing sequence 348/1024
# Processing sequence 349/1024
# Processing sequence 350/1024
# Processing sequence 351/1024
# Processing sequence 352/1024
# Processing sequence 353/1024
# Processing sequence 354/1024
# Processing sequence 355/1024
# Processing sequence 356/1024
# Processing sequence 357/1024
# Processing sequence 358/1024
# Processing sequence 359/1024
# Processing sequence 360/1024
# Processing sequence 361/1024
# Processing sequence 362/1024
# Processing sequence 363/1024
# Processing sequence 364/1024
# Processing sequence 365/1024
# Processing sequence 366/1024
# Processing sequence 367/1024
# Processing sequence 368/1024
# Processing sequence 369/1024
# Processing sequence 370/1024
# Processing sequence 371/1024
# Processing sequence 372/1024
# Processing sequence 373/1024
# Processing sequence 374/1024
# Processing sequence 375/1024
# Processing sequence 376/1024
# Processing sequence 377/1024
# Processing sequence 378/1024
# Processing sequence 379/1024
# Processing sequence 380/1024
# Processing sequence 381/1024
# Processing sequence 382/1024
# Processing sequence 383/1024
# Processing sequence 384/1024
# Processing sequence 385/1024
# Processing sequence 386/1024
# Processing sequence 387/1024
# Processing sequence 388/1024
# Processing sequence 389/1024
# Processing sequence 390/1024
# Processing sequence 391/1024
# Processing sequence 392/1024
# Processing sequence 393/1024
# Processing sequence 394/1024
# Processing sequence 395/1024
# Processing sequence 396/1024
# Processing sequence 397/1024
# Processing sequence 398/1024
# Processing sequence 399/1024
# Processing sequence 400/1024
# Processing sequence 401/1024
# Processing sequence 402/1024
# Processing sequence 403/1024
# Processing sequence 404/1024
# Processing sequence 405/1024
# Processing sequence 406/1024
# Processing sequence 407/1024
# Processing sequence 408/1024
# Processing sequence 409/1024
# Processing sequence 410/1024
# Processing sequence 411/1024
# Processing sequence 412/1024
# Processing sequence 413/1024
# Processing sequence 414/1024
# Processing sequence 415/1024
# Processing sequence 416/1024
# Processing sequence 417/1024
# Processing sequence 418/1024
# Processing sequence 419/1024
# Processing sequence 420/1024
# Processing sequence 421/1024
# Processing sequence 422/1024
# Processing sequence 423/1024
# Processing sequence 424/1024
# Processing sequence 425/1024
# Processing sequence 426/1024
# Processing sequence 427/1024
# Processing sequence 428/1024
# Processing sequence 429/1024
# Processing sequence 430/1024
# Processing sequence 431/1024
# Processing sequence 432/1024
# Processing sequence 433/1024
# Processing sequence 434/1024
# Processing sequence 435/1024
# Processing sequence 436/1024
# Processing sequence 437/1024
# Processing sequence 438/1024
# Processing sequence 439/1024
# Processing sequence 440/1024
# Processing sequence 441/1024
# Processing sequence 442/1024
# Processing sequence 443/1024
# Processing sequence 444/1024
# Processing sequence 445/1024
# Processing sequence 446/1024
# Processing sequence 447/1024
# Processing sequence 448/1024
# Processing sequence 449/1024
# Processing sequence 450/1024
# Processing sequence 451/1024
# Processing sequence 452/1024
# Processing sequence 453/1024
# Processing sequence 454/1024
# Processing sequence 455/1024
# Processing sequence 456/1024
# Processing sequence 457/1024
# Processing sequence 458/1024
# Processing sequence 459/1024
# Processing sequence 460/1024
# Processing sequence 461/1024
# Processing sequence 462/1024
# Processing sequence 463/1024
# Processing sequence 464/1024
# Processing sequence 465/1024
# Processing sequence 466/1024
# Processing sequence 467/1024
# Processing sequence 468/1024
# Processing sequence 469/1024
# Processing sequence 470/1024
# Processing sequence 471/1024
# Processing sequence 472/1024
# Processing sequence 473/1024
# Processing sequence 474/1024
# Processing sequence 475/1024
# Processing sequence 476/1024
# Processing sequence 477/1024
# Processing sequence 478/1024
# Processing sequence 479/1024
# Processing sequence 480/1024
# Processing sequence 481/1024
# Processing sequence 482/1024
# Processing sequence 483/1024
# Processing sequence 484/1024
# Processing sequence 485/1024
# Processing sequence 486/1024
# Processing sequence 487/1024
# Processing sequence 488/1024
# Processing sequence 489/1024
# Processing sequence 490/1024
# Processing sequence 491/1024
# Processing sequence 492/1024
# Processing sequence 493/1024
# Processing sequence 494/1024
# Processing sequence 495/1024
# Processing sequence 496/1024
# Processing sequence 497/1024
# Processing sequence 498/1024
# Processing sequence 499/1024
# Processing sequence 500/1024
# Processing sequence 501/1024
# Processing sequence 502/1024
# Processing sequence 503/1024
# Processing sequence 504/1024
# Processing sequence 505/1024
# Processing sequence 506/1024
# Processing sequence 507/1024
# Processing sequence 508/1024
# Processing sequence 509/1024
# Processing sequence 510/1024
# Processing sequence 511/1024
# Processing sequence 512/1024
# Processing sequence 513/1024
# Processing sequence 514/1024
# Processing sequence 515/1024
# Processing sequence 516/1024
# Processing sequence 517/1024
# Processing sequence 518/1024
# Processing sequence 519/1024
# Processing sequence 520/1024
# Processing sequence 521/1024
# Processing sequence 522/1024
# Processing sequence 523/1024
# Processing sequence 524/1024
# Processing sequence 525/1024
# Processing sequence 526/1024
# Processing sequence 527/1024
# Processing sequence 528/1024
# Processing sequence 529/1024
# Processing sequence 530/1024
# Processing sequence 531/1024
# Processing sequence 532/1024
# Processing sequence 533/1024
# Processing sequence 534/1024
# Processing sequence 535/1024
# Processing sequence 536/1024
# Processing sequence 537/1024
# Processing sequence 538/1024
# Processing sequence 539/1024
# Processing sequence 540/1024
# Processing sequence 541/1024
# Processing sequence 542/1024
# Processing sequence 543/1024
# Processing sequence 544/1024
# Processing sequence 545/1024
# Processing sequence 546/1024
# Processing sequence 547/1024
# Processing sequence 548/1024
# Processing sequence 549/1024
# Processing sequence 550/1024
# Processing sequence 551/1024
# Processing sequence 552/1024
# Processing sequence 553/1024
# Processing sequence 554/1024
# Processing sequence 555/1024
# Processing sequence 556/1024
# Processing sequence 557/1024
# Processing sequence 558/1024
# Processing sequence 559/1024
# Processing sequence 560/1024
# Processing sequence 561/1024
# Processing sequence 562/1024
# Processing sequence 563/1024
# Processing sequence 564/1024
# Processing sequence 565/1024
# Processing sequence 566/1024
# Processing sequence 567/1024
# Processing sequence 568/1024
# Processing sequence 569/1024
# Processing sequence 570/1024
# Processing sequence 571/1024
# Processing sequence 572/1024
# Processing sequence 573/1024
# Processing sequence 574/1024
# Processing sequence 575/1024
# Processing sequence 576/1024
# Processing sequence 577/1024
# Processing sequence 578/1024
# Processing sequence 579/1024
# Processing sequence 580/1024
# Processing sequence 581/1024
# Processing sequence 582/1024
# Processing sequence 583/1024
# Processing sequence 584/1024
# Processing sequence 585/1024
# Processing sequence 586/1024
# Processing sequence 587/1024
# Processing sequence 588/1024
# Processing sequence 589/1024
# Processing sequence 590/1024
# Processing sequence 591/1024
# Processing sequence 592/1024
# Processing sequence 593/1024
# Processing sequence 594/1024
# Processing sequence 595/1024
# Processing sequence 596/1024
# Processing sequence 597/1024
# Processing sequence 598/1024
# Processing sequence 599/1024
# Processing sequence 600/1024
# Processing sequence 601/1024
# Processing sequence 602/1024
# Processing sequence 603/1024
# Processing sequence 604/1024
# Processing sequence 605/1024
# Processing sequence 606/1024
# Processing sequence 607/1024
# Processing sequence 608/1024
# Processing sequence 609/1024
# Processing sequence 610/1024
# Processing sequence 611/1024
# Processing sequence 612/1024
# Processing sequence 613/1024
# Processing sequence 614/1024
# Processing sequence 615/1024
# Processing sequence 616/1024
# Processing sequence 617/1024
# Processing sequence 618/1024
# Processing sequence 619/1024
# Processing sequence 620/1024
# Processing sequence 621/1024
# Processing sequence 622/1024
# Processing sequence 623/1024
# Processing sequence 624/1024
# Processing sequence 625/1024
# Processing sequence 626/1024
# Processing sequence 627/1024
# Processing sequence 628/1024
# Processing sequence 629/1024
# Processing sequence 630/1024
# Processing sequence 631/1024
# Processing sequence 632/1024
# Processing sequence 633/1024
# Processing sequence 634/1024
# Processing sequence 635/1024
# Processing sequence 636/1024
# Processing sequence 637/1024
# Processing sequence 638/1024
# Processing sequence 639/1024
# Processing sequence 640/1024
# Processing sequence 641/1024
# Processing sequence 642/1024
# Processing sequence 643/1024
# Processing sequence 644/1024
# Processing sequence 645/1024
# Processing sequence 646/1024
# Processing sequence 647/1024
# Processing sequence 648/1024
# Processing sequence 649/1024
# Processing sequence 650/1024
# Processing sequence 651/1024
# Processing sequence 652/1024
# Processing sequence 653/1024
# Processing sequence 654/1024
# Processing sequence 655/1024
# Processing sequence 656/1024
# Processing sequence 657/1024
# Processing sequence 658/1024
# Processing sequence 659/1024
# Processing sequence 660/1024
# Processing sequence 661/1024
# Processing sequence 662/1024
# Processing sequence 663/1024
# Processing sequence 664/1024
# Processing sequence 665/1024
# Processing sequence 666/1024
# Processing sequence 667/1024
# Processing sequence 668/1024
# Processing sequence 669/1024
# Processing sequence 670/1024
# Processing sequence 671/1024
# Processing sequence 672/1024
# Processing sequence 673/1024
# Processing sequence 674/1024
# Processing sequence 675/1024
# Processing sequence 676/1024
# Processing sequence 677/1024
# Processing sequence 678/1024
# Processing sequence 679/1024
# Processing sequence 680/1024
# Processing sequence 681/1024
# Processing sequence 682/1024
# Processing sequence 683/1024
# Processing sequence 684/1024
# Processing sequence 685/1024
# Processing sequence 686/1024
# Processing sequence 687/1024
# Processing sequence 688/1024
# Processing sequence 689/1024
# Processing sequence 690/1024
# Processing sequence 691/1024
# Processing sequence 692/1024
# Processing sequence 693/1024
# Processing sequence 694/1024
# Processing sequence 695/1024
# Processing sequence 696/1024
# Processing sequence 697/1024
# Processing sequence 698/1024
# Processing sequence 699/1024
# Processing sequence 700/1024
# Processing sequence 701/1024
# Processing sequence 702/1024
# Processing sequence 703/1024
# Processing sequence 704/1024
# Processing sequence 705/1024
# Processing sequence 706/1024
# Processing sequence 707/1024
# Processing sequence 708/1024
# Processing sequence 709/1024
# Processing sequence 710/1024
# Processing sequence 711/1024
# Processing sequence 712/1024
# Processing sequence 713/1024
# Processing sequence 714/1024
# Processing sequence 715/1024
# Processing sequence 716/1024
# Processing sequence 717/1024
# Processing sequence 718/1024
# Processing sequence 719/1024
# Processing sequence 720/1024
# Processing sequence 721/1024
# Processing sequence 722/1024
# Processing sequence 723/1024
# Processing sequence 724/1024
# Processing sequence 725/1024
# Processing sequence 726/1024
# Processing sequence 727/1024
# Processing sequence 728/1024
# Processing sequence 729/1024
# Processing sequence 730/1024
# Processing sequence 731/1024
# Processing sequence 732/1024
# Processing sequence 733/1024
# Processing sequence 734/1024
# Processing sequence 735/1024
# Processing sequence 736/1024
# Processing sequence 737/1024
# Processing sequence 738/1024
# Processing sequence 739/1024
# Processing sequence 740/1024
# Processing sequence 741/1024
# Processing sequence 742/1024
# Processing sequence 743/1024
# Processing sequence 744/1024
# Processing sequence 745/1024
# Processing sequence 746/1024
# Processing sequence 747/1024
# Processing sequence 748/1024
# Processing sequence 749/1024
# Processing sequence 750/1024
# Processing sequence 751/1024
# Processing sequence 752/1024
# Processing sequence 753/1024
# Processing sequence 754/1024
# Processing sequence 755/1024
# Processing sequence 756/1024
# Processing sequence 757/1024
# Processing sequence 758/1024
# Processing sequence 759/1024
# Processing sequence 760/1024
# Processing sequence 761/1024
# Processing sequence 762/1024
# Processing sequence 763/1024
# Processing sequence 764/1024
# Processing sequence 765/1024
# Processing sequence 766/1024
# Processing sequence 767/1024
# Processing sequence 768/1024
# Processing sequence 769/1024
# Processing sequence 770/1024
# Processing sequence 771/1024
# Processing sequence 772/1024
# Processing sequence 773/1024
# Processing sequence 774/1024
# Processing sequence 775/1024
# Processing sequence 776/1024
# Processing sequence 777/1024
# Processing sequence 778/1024
# Processing sequence 779/1024
# Processing sequence 780/1024
# Processing sequence 781/1024
# Processing sequence 782/1024
# Processing sequence 783/1024
# Processing sequence 784/1024
# Processing sequence 785/1024
# Processing sequence 786/1024
# Processing sequence 787/1024
# Processing sequence 788/1024
# Processing sequence 789/1024
# Processing sequence 790/1024
# Processing sequence 791/1024
# Processing sequence 792/1024
# Processing sequence 793/1024
# Processing sequence 794/1024
# Processing sequence 795/1024
# Processing sequence 796/1024
# Processing sequence 797/1024
# Processing sequence 798/1024
# Processing sequence 799/1024
# Processing sequence 800/1024
# Processing sequence 801/1024
# Processing sequence 802/1024
# Processing sequence 803/1024
# Processing sequence 804/1024
# Processing sequence 805/1024
# Processing sequence 806/1024
# Processing sequence 807/1024
# Processing sequence 808/1024
# Processing sequence 809/1024
# Processing sequence 810/1024
# Processing sequence 811/1024
# Processing sequence 812/1024
# Processing sequence 813/1024
# Processing sequence 814/1024
# Processing sequence 815/1024
# Processing sequence 816/1024
# Processing sequence 817/1024
# Processing sequence 818/1024
# Processing sequence 819/1024
# Processing sequence 820/1024
# Processing sequence 821/1024
# Processing sequence 822/1024
# Processing sequence 823/1024
# Processing sequence 824/1024
# Processing sequence 825/1024
# Processing sequence 826/1024
# Processing sequence 827/1024
# Processing sequence 828/1024
# Processing sequence 829/1024
# Processing sequence 830/1024
# Processing sequence 831/1024
# Processing sequence 832/1024
# Processing sequence 833/1024
# Processing sequence 834/1024
# Processing sequence 835/1024
# Processing sequence 836/1024
# Processing sequence 837/1024
# Processing sequence 838/1024
# Processing sequence 839/1024
# Processing sequence 840/1024
# Processing sequence 841/1024
# Processing sequence 842/1024
# Processing sequence 843/1024
# Processing sequence 844/1024
# Processing sequence 845/1024
# Processing sequence 846/1024
# Processing sequence 847/1024
# Processing sequence 848/1024
# Processing sequence 849/1024
# Processing sequence 850/1024
# Processing sequence 851/1024
# Processing sequence 852/1024
# Processing sequence 853/1024
# Processing sequence 854/1024
# Processing sequence 855/1024
# Processing sequence 856/1024
# Processing sequence 857/1024
# Processing sequence 858/1024
# Processing sequence 859/1024
# Processing sequence 860/1024
# Processing sequence 861/1024
# Processing sequence 862/1024
# Processing sequence 863/1024
# Processing sequence 864/1024
# Processing sequence 865/1024
# Processing sequence 866/1024
# Processing sequence 867/1024
# Processing sequence 868/1024
# Processing sequence 869/1024
# Processing sequence 870/1024
# Processing sequence 871/1024
# Processing sequence 872/1024
# Processing sequence 873/1024
# Processing sequence 874/1024
# Processing sequence 875/1024
# Processing sequence 876/1024
# Processing sequence 877/1024
# Processing sequence 878/1024
# Processing sequence 879/1024
# Processing sequence 880/1024
# Processing sequence 881/1024
# Processing sequence 882/1024
# Processing sequence 883/1024
# Processing sequence 884/1024
# Processing sequence 885/1024
# Processing sequence 886/1024
# Processing sequence 887/1024
# Processing sequence 888/1024
# Processing sequence 889/1024
# Processing sequence 890/1024
# Processing sequence 891/1024
# Processing sequence 892/1024
# Processing sequence 893/1024
# Processing sequence 894/1024
# Processing sequence 895/1024
# Processing sequence 896/1024
# Processing sequence 897/1024
# Processing sequence 898/1024
# Processing sequence 899/1024
# Processing sequence 900/1024
# Processing sequence 901/1024
# Processing sequence 902/1024
# Processing sequence 903/1024
# Processing sequence 904/1024
# Processing sequence 905/1024
# Processing sequence 906/1024
# Processing sequence 907/1024
# Processing sequence 908/1024
# Processing sequence 909/1024
# Processing sequence 910/1024
# Processing sequence 911/1024
# Processing sequence 912/1024
# Processing sequence 913/1024
# Processing sequence 914/1024
# Processing sequence 915/1024
# Processing sequence 916/1024
# Processing sequence 917/1024
# Processing sequence 918/1024
# Processing sequence 919/1024
# Processing sequence 920/1024
# Processing sequence 921/1024
# Processing sequence 922/1024
# Processing sequence 923/1024
# Processing sequence 924/1024
# Processing sequence 925/1024
# Processing sequence 926/1024
# Processing sequence 927/1024
# Processing sequence 928/1024
# Processing sequence 929/1024
# Processing sequence 930/1024
# Processing sequence 931/1024
# Processing sequence 932/1024
# Processing sequence 933/1024
# Processing sequence 934/1024
# Processing sequence 935/1024
# Processing sequence 936/1024
# Processing sequence 937/1024
# Processing sequence 938/1024
# Processing sequence 939/1024
# Processing sequence 940/1024
# Processing sequence 941/1024
# Processing sequence 942/1024
# Processing sequence 943/1024
# Processing sequence 944/1024
# Processing sequence 945/1024
# Processing sequence 946/1024
# Processing sequence 947/1024
# Processing sequence 948/1024
# Processing sequence 949/1024
# Processing sequence 950/1024
# Processing sequence 951/1024
# Processing sequence 952/1024
# Processing sequence 953/1024
# Processing sequence 954/1024
# Processing sequence 955/1024
# Processing sequence 956/1024
# Processing sequence 957/1024
# Processing sequence 958/1024
# Processing sequence 959/1024
# Processing sequence 960/1024
# Processing sequence 961/1024
# Processing sequence 962/1024
# Processing sequence 963/1024
# Processing sequence 964/1024
# Processing sequence 965/1024
# Processing sequence 966/1024
# Processing sequence 967/1024
# Processing sequence 968/1024
# Processing sequence 969/1024
# Processing sequence 970/1024
# Processing sequence 971/1024
# Processing sequence 972/1024
# Processing sequence 973/1024
# Processing sequence 974/1024
# Processing sequence 975/1024
# Processing sequence 976/1024
# Processing sequence 977/1024
# Processing sequence 978/1024
# Processing sequence 979/1024
# Processing sequence 980/1024
# Processing sequence 981/1024
# Processing sequence 982/1024
# Processing sequence 983/1024
# Processing sequence 984/1024
# Processing sequence 985/1024
# Processing sequence 986/1024
# Processing sequence 987/1024
# Processing sequence 988/1024
# Processing sequence 989/1024
# Processing sequence 990/1024
# Processing sequence 991/1024
# Processing sequence 992/1024
# Processing sequence 993/1024
# Processing sequence 994/1024
# Processing sequence 995/1024
# Processing sequence 996/1024
# Processing sequence 997/1024
# Processing sequence 998/1024
# Processing sequence 999/1024
# Processing sequence 1000/1024
# Processing sequence 1001/1024
# Processing sequence 1002/1024
# Processing sequence 1003/1024
# Processing sequence 1004/1024
# Processing sequence 1005/1024
# Processing sequence 1006/1024
# Processing sequence 1007/1024
# Processing sequence 1008/1024
# Processing sequence 1009/1024
# Processing sequence 1010/1024
# Processing sequence 1011/1024
# Processing sequence 1012/1024
# Processing sequence 1013/1024
# Processing sequence 1014/1024
# Processing sequence 1015/1024
# Processing sequence 1016/1024
# Processing sequence 1017/1024
# Processing sequence 1018/1024
# Processing sequence 1019/1024
# Processing sequence 1020/1024
# Processing sequence 1021/1024
# Processing sequence 1022/1024
# Processing sequence 1023/1024
# Processing sequence 1024/1024
# Saved 1024 sequences to ../data/processed/Visa_2024-09-06.pkl
