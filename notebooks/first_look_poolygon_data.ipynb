# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "../data/raw/2024-09-30.csv"

# %%
df = pd.read_csv(path)
# Out:
# /var/folders/js/9hpr3tt17xd6ttv9xy3zrhw80000gn/T/ipykernel_31880/3280352130.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
df
# Out:
#          ticker   conditions  correction  exchange              id  \
# 0             A        12,37           0        12  62879133549420
# 1             A      7,12,37           0         4  71675224797752
# 2             A      7,12,37           0         4  71675225195569
# 3             A      7,12,37           0         4  71675239681075
# 4             A  14,12,37,41           0        11  52983525425976
# ...         ...          ...         ...       ...             ...
# 76731247    ZZZ          NaN           0         4              12
# 76731248    ZZZ           37           0        11               4
# 76731249    ZZZ           15           0        11               5
# 76731250    ZZZ           15           0        12               7
# 76731251    ZZZ        38,41           0        12               8
#
#           participant_timestamp     price  sequence_number  \
# 0           1727696995110294908  147.7000            10820
# ...

# %%
dfa = df[df.ticker == "A"]

# %%
len(dfa)
# Out:
# 23323

# %%
dfa.describe()
# Out:
#          correction      exchange            id  participant_timestamp  \
# count  23323.000000  23323.000000  2.332300e+04           2.332300e+04
# mean       0.002315      9.715688  6.182477e+13           1.727717e+18
# std        0.145226      5.229760  7.953956e+12           7.738864e+12
# min        0.000000      1.000000  5.298353e+13           1.727694e+18
# 25%        0.000000      4.000000  5.298354e+13           1.727710e+18
# 50%        0.000000     10.000000  6.287952e+13           1.727719e+18
# 75%        0.000000     12.000000  7.168816e+13           1.727725e+18
# max       10.000000     21.000000  7.937218e+13           1.727740e+18
#
#               price  sequence_number  sip_timestamp           size     tape  \
# count  23323.000000     2.332300e+04   2.332300e+04   23323.000000  23323.0
# mean     147.729227     9.537418e+05   1.727717e+18     124.790593      1.0
# std        0.436946     5.055006e+05   7.737951e+12    5452.443602      0.0
# ...

# %%
ts = dfa.sip_timestamp
ys = dfa.price

# %%
dfa.sip_timestamp = pd.to_datetime(dfa.sip_timestamp)
# Out:
# /var/folders/js/9hpr3tt17xd6ttv9xy3zrhw80000gn/T/ipykernel_31880/4286049335.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa.sip_timestamp = pd.to_datetime(dfa.sip_timestamp)

# %%
plt.figure(figsize = (20,8))
plt.plot(ts,ys)
plt.show()

# %%
dfa
# Out:
#       ticker   conditions  correction  exchange              id  \
# 0          A        12,37           0        12  62879133549420
# 1          A      7,12,37           0         4  71675224797752
# 2          A      7,12,37           0         4  71675225195569
# 3          A      7,12,37           0         4  71675239681075
# 4          A  14,12,37,41           0        11  52983525425976
# ...      ...          ...         ...       ...             ...
# 23318      A        38,41           0        10  52983560688201
# 23319      A           15           0        10  52983560688202
# 23320      A        12,37           0        11  52983593907541
# 23321      A        12,37           0        11  52983593907765
# 23322      A        12,37           0        11  52983593907766
#
#        participant_timestamp   price  sequence_number  \
# 0        1727696995110294908  147.70            10820
# 1        1727694478968094000  148.06            12002
# ...

# %%
pubm = df[df.ticker == "PUBM"]

# %%
pubm
# Out:
#          ticker conditions  correction  exchange    id  participant_timestamp  \
# 52816845   PUBM      12,37           0        12     1    1727694017379737079
# 52816846   PUBM         12           0         8     1    1727694756701212000
# 52816847   PUBM      12,37           0         8     2    1727694756701212000
# 52816848   PUBM         12           0         4     1    1727694000159698010
# 52816849   PUBM      12,37           0         4     1    1727697764976388967
# ...         ...        ...         ...       ...   ...                    ...
# 52821900   PUBM      12,37           0         4  2079    1727726410848000000
# 52821901   PUBM   12,22,41           0         4  2080    1727726534147295000
# 52821902   PUBM   12,22,41           0         4  2081    1727726575148724000
# 52821903   PUBM   12,22,41           0         4  2082    1727726577946846000
# 52821904   PUBM      12,37           0         4  2083    1727737372036242379
#
# ...

# %%
pubm.describe()
# Out:
#        correction     exchange           id  participant_timestamp  \
# count      5060.0  5060.000000  5060.000000           5.060000e+03
# mean          0.0     9.171937   634.927470           1.727718e+18
# std           0.0     5.237669   586.995369           7.721356e+12
# min           0.0     1.000000     1.000000           1.727694e+18
# 25%           0.0     4.000000   125.000000           1.727712e+18
# 50%           0.0    10.000000   425.000000           1.727720e+18
# 75%           0.0    12.000000  1057.250000           1.727725e+18
# max           0.0    21.000000  2083.000000           1.727737e+18
#
#              price  sequence_number  sip_timestamp          size    tape  \
# count  5060.000000     5.060000e+03   5.060000e+03   5060.000000  5060.0
# mean     14.885399     3.315492e+06   1.727718e+18     67.793478     3.0
# std       0.087425     1.475107e+06   7.719312e+12    892.291643     0.0
# ...

# %%
domo = df[df.ticker == "DOMO"]

# %%
domo
# Out:
#          ticker conditions  correction  exchange    id  participant_timestamp  \
# 19496290   DOMO    17,9,41           0        12     1    1727703001212824004
# 19496291   DOMO         16           0        12     2    1727703001212848275
# 19496292   DOMO         37           0         4     1    1727703008507000000
# 19496293   DOMO         37           0         4     2    1727703011672000000
# 19496294   DOMO   10,37,41           0         4     3    1727703019277000000
# ...         ...        ...         ...       ...   ...                    ...
# 19501843   DOMO         12           0         4  2543    1727726406203000000
# 19501844   DOMO      12,37           0         4  2544    1727726455131267725
# 19501845   DOMO      12,37           0        11   380    1727726812161479761
# 19501846   DOMO      12,37           0         4  2545    1727730227264000000
# 19501847   DOMO      12,37           0         4    31    1727730253497016208
#
# ...

# %%
domo.isna().sum()
# Out:
# ticker                     0
# conditions               995
# correction                 0
# exchange                   0
# id                         0
# participant_timestamp      0
# price                      0
# sequence_number            0
# sip_timestamp              0
# size                       0
# tape                       0
# trf_id                     0
# trf_timestamp              0
# dtype: int64

# %%
domo.describe()
# Out:
#        correction     exchange           id  participant_timestamp  \
# count      5558.0  5558.000000  5558.000000           5.558000e+03
# mean          0.0     8.899604   788.647175           1.727718e+18
# std           0.0     5.303358   725.587918           7.228556e+12
# min           0.0     1.000000     1.000000           1.727703e+18
# 25%           0.0     4.000000   159.250000           1.727712e+18
# 50%           0.0     8.000000   560.500000           1.727720e+18
# 75%           0.0    12.000000  1255.000000           1.727725e+18
# max           0.0    21.000000  2545.000000           1.727730e+18
#
#              price  sequence_number  sip_timestamp          size    tape  \
# count  5558.000000     5.558000e+03   5.558000e+03   5558.000000  5558.0
# mean      7.522792     3.128787e+06   1.727718e+18     69.969773     3.0
# std       0.060315     1.326453e+06   7.228554e+12    868.232607     0.0
# ...

# %%
domo.sip_timestamp = pd.to_datetime(domo.sip_timestamp)
# Out:
# /var/folders/js/9hpr3tt17xd6ttv9xy3zrhw80000gn/T/ipykernel_31880/2329141345.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   domo.sip_timestamp = pd.to_datetime(domo.sip_timestamp)

# %%
ts2 = domo.sip_timestamp
ys2 = domo.price

# %%
ys2
# Out:
# 19496290    7.2700
# 19496291    7.2700
# 19496292    7.2700
# 19496293    7.2352
# 19496294    7.2700
#              ...
# 19501843    7.5100
# 19501844    7.4200
# 19501845    7.4300
# 19501846    7.5500
# 19501847    7.5500
# Name: price, Length: 5558, dtype: float64

# %%
plt.figure(figsize = (15,7))

plt.plot(ts, ys / 140)
plt.plot(ts2, ys2 / 7)
plt.show()

# %%
df1 = df[df.ticker == "MS"]
df2 = df[df.ticker == "GS"]

df1.sip_timestamp = pd.to_datetime(df1.sip_timestamp)
df2.sip_timestamp = pd.to_datetime(df2.sip_timestamp)
# Out:
# /var/folders/js/9hpr3tt17xd6ttv9xy3zrhw80000gn/T/ipykernel_31880/43136746.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.sip_timestamp = pd.to_datetime(df1.sip_timestamp)
# /var/folders/js/9hpr3tt17xd6ttv9xy3zrhw80000gn/T/ipykernel_31880/43136746.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.sip_timestamp = pd.to_datetime(df2.sip_timestamp)

# %%
ts1 = df1.sip_timestamp
ts2 = df2.sip_timestamp

ys1 = df1.price
ys2 = df2.price

# %%
plt.figure(figsize = (20,8))

plt.plot(ts1, ys1 / (ys1.mean()))
plt.plot(ts2, ys2 / (ys2.mean()))
plt.show()

# %%
df = pd.read_csv("../data/processed/2024-09-20.csv")

# %%
df
# Out:
#                sip_timestamp  ask_price  ask_size  bid_price  bid_size  \
# 0        1726821078191678471    274.580       1.0    250.000       1.0
# 1        1726822578623640357    274.590       1.0    250.000       1.0
# 2        1726823000570414437    274.580       1.0    250.000       1.0
# 3        1726823212297325061    274.580       1.0    250.000       1.0
# 4        1726824423626109642    274.580       1.0    250.000       1.0
# ...                      ...        ...       ...        ...       ...
# 4731967  1726874939210770944      0.715      19.0      0.641      10.0
# 4731968  1726874939210775552      0.715      19.0      0.641      10.0
# 4731969  1726876800014751488      0.715      19.0      0.641      10.0
# 4731970  1726876800014751488      0.715      19.0      0.641      10.0
# 4731971  1726876800046286592      0.715      19.0      0.601       1.0
#
#          last_trade_price  last_trade_size
# 0                269.9900              5.0
# ...
