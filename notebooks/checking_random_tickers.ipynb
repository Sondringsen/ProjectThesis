# %% [markdown]
# <h1>Checking random tickers</h1>
# <h3>This is done to ensure that the metadata of the random tickers are representative of the entire dataset</h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
meta_data = pd.read_csv("../data/raw/meta_data.csv", index_col=0)

exclude_columns = ["ticker"]
categorical_columns = ["sectorKey", "industryKey"]
numerical_columns = meta_data.columns.drop(categorical_columns + exclude_columns)

# Removing infinite values
meta_data[numerical_columns] = meta_data[numerical_columns].replace([np.inf, -np.inf], np.nan)

random_tickers = pd.read_csv("../data/raw/random_tickers.csv", index_col=0)

meta_data_random = meta_data.loc[random_tickers.index, :]

# %% [markdown]
# <h3>Description of data</h3>

# %%
meta_data.describe()
# Out:
#        fullTimeEmployees    auditRisk    boardRisk  compensationRisk  \
# count       2.593000e+03  2286.000000  2286.000000       2286.000000
# mean        1.582519e+04     5.142170     4.961505          4.787402
# std         7.714590e+04     2.800031     2.814981          2.760988
# min         1.000000e+00     1.000000     1.000000          1.000000
# 25%         3.910000e+02     3.000000     3.000000          2.000000
# 50%         2.188000e+03     5.000000     5.000000          4.000000
# 75%         9.750000e+03     7.000000     7.000000          7.000000
# max         2.100000e+06    10.000000    10.000000         10.000000
#
#        shareHolderRightsRisk  overallRisk  dividendRate  dividendYield  \
# count            2286.000000  2286.000000   1419.000000    1419.000000
# mean                4.978128     4.793526      1.746808       0.031288
# std                 2.823697     2.740453      2.089796       0.047998
# min                 1.000000     1.000000      0.020000       0.000200
# 25%                 3.000000     2.000000      0.600000       0.012800
# 50%                 5.000000     4.000000      1.120000       0.023800
# 75%                 7.000000     7.000000      2.060000       0.038800
# max                10.000000    10.000000     35.000000       1.459900
#
#        fiveYearAvgDividendYield         beta  ...  debtToEquity  \
# count               1471.000000  2638.000000  ...    2160.00000
# mean                   3.119089     1.153232  ...     177.52607
# std                    2.935906     0.602973  ...     811.92651
# min                    0.020000    -3.411000  ...       0.01000
# 25%                    1.450000     0.777250  ...      23.06275
# 50%                    2.550000     1.088000  ...      65.54100
# 75%                    3.990000     1.453750  ...     141.25200
# max                   59.620000     5.515000  ...   30119.25200
#
#        returnOnAssets  returnOnEquity  freeCashflow  operatingCashflow  \
# count     2643.000000     2498.000000  2.296000e+03       2.636000e+03
# mean        -0.001987       -0.077999  6.530611e+08       1.215254e+09
# std          0.175619        1.984666  3.635829e+09       6.060402e+09
# min         -3.264990      -63.420288 -3.384138e+10      -7.581000e+10
# 25%          0.002720       -0.030425 -4.092875e+06       1.388475e+07
# 50%          0.026520        0.079765  6.446044e+07       1.548060e+08
# 75%          0.058250        0.161183  3.915955e+08       6.836655e+08
# max          0.715790       37.833910  8.615812e+10       1.185480e+11
#
#        earningsGrowth  revenueGrowth  grossMargins  ebitdaMargins  \
# count     1627.000000    2534.000000   2269.000000    2143.000000
# mean         0.883888       0.167367      0.418808       0.125853
# std          9.939576       2.835726      0.342905       0.363796
# min         -0.995000      -1.000000     -2.974810      -2.963980
# 25%         -0.225000      -0.051000      0.244340       0.056440
# 50%          0.038000       0.030000      0.402900       0.140380
# 75%          0.319000       0.108000      0.616130       0.259250
# max        308.278000     129.697000      1.039340       0.948330
#
#        operatingMargins
# count       2592.000000
# mean         -14.485850
# std          217.324929
# min        -5349.000000
# 25%            0.021367
# 50%            0.109840
# 75%            0.225842
# max           19.557850
#
# [8 rows x 47 columns]

# %%
meta_data_random.describe()
# Out:
#        fullTimeEmployees  auditRisk  boardRisk  compensationRisk  \
# count          92.000000  87.000000  87.000000         87.000000
# mean        11626.228261   5.287356   4.896552          4.942529
# std         24920.874153   2.667235   2.685164          2.585093
# min            11.000000   1.000000   1.000000          1.000000
# 25%           435.750000   3.000000   3.000000          3.000000
# 50%          3596.000000   5.000000   5.000000          5.000000
# 75%         13125.000000   7.000000   7.000000          7.000000
# max        206000.000000  10.000000  10.000000         10.000000
#
#        shareHolderRightsRisk  overallRisk  dividendRate  dividendYield  \
# count              87.000000    87.000000     58.000000      58.000000
# mean                4.781609     4.689655      1.274483       0.028231
# std                 2.911186     2.611737      1.274708       0.025098
# min                 1.000000     1.000000      0.040000       0.003400
# 25%                 2.000000     3.000000      0.340000       0.012300
# 50%                 5.000000     4.000000      0.890000       0.022050
# 75%                 6.500000     6.500000      1.760000       0.037200
# max                10.000000    10.000000      5.440000       0.131100
#
#        fiveYearAvgDividendYield       beta  ...  debtToEquity  returnOnAssets  \
# count                 62.000000  95.000000  ...     77.000000       94.000000
# mean                   3.209355   1.252811  ...    213.152312        0.008816
# std                    3.241324   0.707522  ...    714.404837        0.113465
# min                    0.280000   0.083000  ...      0.208000       -0.633270
# 25%                    1.372500   0.854000  ...     23.041000        0.005530
# 50%                    2.260000   1.153000  ...     56.253000        0.027185
# 75%                    4.085000   1.484000  ...    143.540000        0.063505
# max                   18.870000   5.515000  ...   5715.734000        0.162610
#
#        returnOnEquity  freeCashflow  operatingCashflow  earningsGrowth  \
# count       88.000000  8.000000e+01       9.400000e+01        60.00000
# mean        -0.025094  7.415834e+08       1.018714e+09         0.24520
# std          0.403030  2.448520e+09       2.901124e+09         1.01497
# min         -1.695000 -7.883750e+08      -3.762940e+08        -0.96700
# 25%         -0.009015 -7.999625e+06       1.924218e+07        -0.28575
# 50%          0.066820  7.445968e+07       1.765260e+08         0.05800
# 75%          0.149285  3.079968e+08       5.698840e+08         0.33800
# max          0.588550  1.469663e+10       2.021300e+10         5.63900
#
#        revenueGrowth  grossMargins  ebitdaMargins  operatingMargins
# count      92.000000     80.000000      75.000000         94.000000
# mean        0.120141      0.401231       0.166111         -0.478543
# std         0.893144      0.427478       0.229171          3.868063
# min        -0.788000     -2.465060      -0.855890        -24.355730
# 25%        -0.055000      0.245298       0.093935          0.047390
# 50%         0.042500      0.423015       0.166950          0.120925
# 75%         0.122000      0.607272       0.230030          0.206883
# max         8.321000      1.000000       0.698320         10.045450
#
# [8 rows x 47 columns]

# %% [markdown]
# <h3>T-statistics for all columns</h3>

# %%
t_stat = (meta_data[numerical_columns].mean() - meta_data_random[numerical_columns].mean()) / meta_data[numerical_columns].std()
t_stat
# Out:
# fullTimeEmployees               0.054429
# auditRisk                      -0.051852
# boardRisk                       0.023074
# compensationRisk               -0.056185
# shareHolderRightsRisk           0.069596
# overallRisk                     0.037903
# dividendRate                    0.226015
# dividendYield                   0.063680
# fiveYearAvgDividendYield       -0.030745
# beta                           -0.165146
# trailingPE                      0.088263
# forwardPE                       0.005366
# marketCap                       0.034992
# priceToSalesTrailing12Months    0.028128
# enterpriseValue                 0.024192
# profitMargins                   0.017812
# floatShares                     0.040112
# sharesShort                    -0.044376
# sharesShortPriorMonth          -0.041151
# heldPercentInsiders             0.120569
# heldPercentInstitutions        -0.131773
# shortRatio                      0.049172
# priceToBook                    -0.005283
# earningsQuarterlyGrowth         0.047073
# trailingEps                    -0.025690
# pegRatio                       -0.022093
# enterpriseToRevenue            -0.000177
# enterpriseToEbitda             -0.010904
# targetHighPrice                 0.072094
# targetLowPrice                  0.058319
# recommendationMean             -0.076939
# numberOfAnalystOpinions         0.024238
# totalCash                       0.055935
# ebitda                          0.040900
# totalDebt                       0.061979
# quickRatio                     -0.029445
# totalRevenue                    0.065483
# debtToEquity                   -0.043879
# returnOnAssets                 -0.061512
# returnOnEquity                 -0.026657
# freeCashflow                   -0.024347
# operatingCashflow               0.032430
# earningsGrowth                  0.064257
# revenueGrowth                   0.016654
# grossMargins                    0.051259
# ebitdaMargins                  -0.110660
# operatingMargins               -0.064453
# dtype: float64

# %% [markdown]
# <h3>Metadata contains both na-values and infinite values (infinite values are replaced with nan-values when loading the data).</h3>

# %%
print(meta_data.isna().sum())
# Out:
# ticker                             0
# sectorKey                       1757
# industryKey                     1757
# fullTimeEmployees                100
# auditRisk                        407
# boardRisk                        407
# compensationRisk                 407
# shareHolderRightsRisk            407
# overallRisk                      407
# dividendRate                    1274
# dividendYield                   1274
# fiveYearAvgDividendYield        1222
# beta                              55
# trailingPE                       871
# forwardPE                        195
# marketCap                         48
# priceToSalesTrailing12Months     101
# enterpriseValue                   62
# profitMargins                    202
# floatShares                       48
# sharesShort                       48
# sharesShortPriorMonth             48
# heldPercentInsiders               50
# heldPercentInstitutions           48
# shortRatio                        48
# priceToBook                      218
# earningsQuarterlyGrowth         1037
# trailingEps                       56
# pegRatio                         642
# enterpriseToRevenue              115
# enterpriseToEbitda               424
# targetHighPrice                  375
# targetLowPrice                   375
# recommendationMean               266
# numberOfAnalystOpinions          375
# totalCash                         62
# ebitda                           411
# totalDebt                        105
# quickRatio                       326
# totalRevenue                     101
# debtToEquity                     533
# returnOnAssets                    50
# returnOnEquity                   195
# freeCashflow                     397
# operatingCashflow                 57
# earningsGrowth                  1066
# revenueGrowth                    159
# grossMargins                     424
# ebitdaMargins                    550
# operatingMargins                 101
# dtype: int64

# %% [markdown]
# <h3>Plotting histograms of all data and random subset data</h3>

# %%
fig, axs = plt.subplots(numerical_columns.shape[0], figsize=(10, 50))

fig.suptitle("Histograms of columns")

for i, col in enumerate(numerical_columns):
    meta_data_col = meta_data[col].dropna()
    meta_data_col = meta_data_col.map
    axs[i].hist(meta_data[col].dropna(), alpha=0.5, label=f'{col} (full)', density=True, bins=20)
    axs[i].hist(meta_data_random[col], alpha=0.5, label=f'{col}, (random)', density=True, bins=20)
    axs[i].legend()

fig.tight_layout()
